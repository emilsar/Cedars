# %% [markdown]
# <a href="https://colab.research.google.com/github/emilsar/Cedars/blob/main/Intro_to_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
is_positive = True
is_negative = False
print (type(is_positive))
# Out:
# <class 'bool'>

# %%
ratio=0.67
is_high = ratio>0.6
is_exact = 0.67==ratio
print(is_exact)
# Out:
# True

# %%
# !git clone http://github.com/emilsar/Cedars.git
# Out:
# Cloning into 'Cedars'...
# ...
# remote: Enumerating objects: 1127, done.
# remote: Counting objects: 100% (39/39), done.
# remote: Compressing objects: 100% (39/39), done.
# remote: Total 1127 (delta 19), reused 4 (delta 0), pack-reused 1088 (from 2)
# Receiving objects: 100% (1127/1127), 1.22 GiB | 28.61 MiB/s, done.
# Resolving deltas: 100% (396/396), done.
# Updating files: 100% (891/891), done.

# %%
# %cd Cedars/Project3
# Out:
# /content/Cedars/Project3

# %%
list = ["apple","banana","cherry"]
for k in list:
  print (k)
# Out:
# apple
# banana
# cherry

# %%
for i, k in enumerate(list):
  print (f"{i}:{k}")
# Out:
# 0:apple
# 1:banana
# 2:cherry

# %%
print(type(enumerate(list)))
# Out:
# <class 'enumerate'>

# %%
list=[1,2,3,0,7,4,5]
squared=[x**2 for x in list if x>1]
print(squared)
# Out:
# [4, 9, 49, 16, 25]
